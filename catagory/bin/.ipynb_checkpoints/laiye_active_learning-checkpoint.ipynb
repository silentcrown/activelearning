# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import random
from intent_classify import IntentClassify
from gensim import corpora, models, similarities,matutils
from fasttext_util import FasttextClassifier
import time
from collections import Counter
import re
from url import Searcher
import pickle
import matplotlib.pyplot as plt
from sklearn import metrics
# %matplotlib inline
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.295 seconds.
# Prefix dict has been built succesfully.
# load 1006 user-define jieba dict success!

# %%
class word():    
    def __init__(self):
        self.word_to_vec = {}
        self.dictionary = corpora.dictionary.Dictionary()
        self.dic = self.dictionary.load('../util/new/laiye/corpus.dict')
        self.tfidf = models.TfidfModel.load('../util/new/laiye/corpus.tfidf_model')  
        
    def remove_punctuation(self, line):
        rule = re.compile(ur"[^a-zA-Z0-9\u4e00-\u9fa5]")
        line = rule.sub('',line)
        return line        

    def stopwordslist(self, filepath):  
        stopwords = [line.strip() for line in open(filepath, 'r').readlines()]  
        return stopwords  


    # 对句子进行分词  
    def jieba_cut(self, sentence):  
        sentence_seged = jieba.cut(sentence.strip())  
        stopwords = stopwordslist('../util/new/laiye/stopwords.txt')  # 这里加载停用词的路径  
        outstr = ''  
        for word in sentence_seged:  
            if word.encode('utf-8') not in stopwords:  
                if word.encode('utf-8') != '\t' and word != '\t':  
                    outstr += word
                    outstr += " "  
        return outstr.strip().split(' ')

    def get_word2vec(self):
        with open('../util/new/laiye/w2v_sgns_win1_d80.kv') as f:
            data = [x.split(' ') for x in f.readlines()[1:]]
            words = [d[0] for d in data]
            vecs = np.array([d[1: -1] for d in data], dtype= 'float64')
            for i in range(len(words)):
                word = words[i]
                self.word_to_vec[word] = vecs[i]

    def get_tf_idf_of_query(self, query, dic, tfidf):      
        vec_bow = dic.doc2bow(query)
        vec_tfidf = tfidf[vec_bow]
        tp = [0.0] * len(query)
        ids = [tid[0] for tid in vec_tfidf]
        flags = [0] * len(query)
        count = 0.00001
        for j in range(len(query)):
            for i in range(len(ids)):
                if self.dic[ids[i]] == query[j]:
                    tp[j] = vec_tfidf[i][1]
                    flags[j] = 1
                    count += 1
                    break
        sums = sum(tp)
        #print ','.join(query)
        for i in range(len(flags)):
            if flags[i] == 1:
                continue
            tp[i] = 1.0 * sums / count
                    
        # apply l1-norm to tfidf value
        #tfidf = matutils.unitvec(vec_tfidf, norm = 'l1')   
        return tp

    def get_vectors_of_data_cut(self, data):
        vecs = []
        for i in range(len(data)):
            vec = []
            d_line = data[i].split(' ')
            tfidfs = self.get_tf_idf_of_query(d_line, self.dic, self.tfidf)
            s = sum(tfidfs)
            for j in range(len(d_line)):
                if d_line[j].encode('utf-8') in self.word_to_vec:
                    if s == 0:
                        vec.append([0.0] * len(self.word_to_vec['家']))
                    else:
                        vec.append((tfidfs[j] / s) * self.word_to_vec[d_line[j].encode('utf-8')])
            if len(vec) == 0:
                vec.append([0.0] * len(self.word_to_vec['家']))
            vecs.append(np.sum(np.array(vec), axis = 0))
        return np.array(vecs)

# %%
class data():
    
    def __init__(self, data_path, text_path, knowledge_path, label_path):
        self.data = open(data_path, 'r').readlines()
        self.knowledge = open(knowledge_path, 'r').readlines()
        self.text_path = text_path
        self.label = open(label_path, 'r').readlines()
        self.indexes = []
        self.labeled_indexes = []
        self.unlabeled_indexes = []
        self.test_indexes = []
        self.questions_match_dict = []
        self.t_map = {}
        self.range = [0.000001,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95,1.0]
        self.range_result = {0.05:0, 0.1:0,0.15:0, 0.2:0,0.25:0, 0.3:0,0.35:0, 0.4:0,0.45:0,0.5:0, 0.55:0,0.6:0,0.65:0,0.7:0, 0.75:0,0.8:0,0.85:0,0.9:0,0.95:0, 1.0:0}
        self.dic = {}
        
    def get_texts(self, text_path):
        texts = []
        knowledges = []
        labels = []
        for i in range(len(self.data)):
            for key in self.data[i].split('||'):
                if key.strip() != '':
                    key = key.strip().replace('\n','')
                    texts.append(key) 
                    knowledges.append(self.knowledge[i].strip().replace('\n',''))
                    labels.append(self.label[i].strip().replace('\n',''))
        text_csv = pd.DataFrame({'text':texts, 'knowledge':knowledges, 'label':labels})
        text_csv.to_csv(text_path, index = False, encoding = 'utf-8')
        
    def split_real_labeled_unlabeld_and_test(self):
        self.get_texts(self.text_path)
        data = pd.read_csv(self.text_path)
        undefined = pd.read_csv('../data/ooooo.csv')
        labeled, unlabeled = data, undefined
        samp_index = range(len(list(undefined['rq_question'])))
        random.shuffle(samp_index)
        samp_index = samp_index[:10000]
        remain = []
        res = []
        l = list(data['text'])
        for i in range(len(l)):
            res.append((l[i], i))
        l_u = list(undefined['rq_question'])
        for i in range(len(l_u)):
            if i in samp_index:
                res.append((l_u[i], i))
        pickle.dump(res, open('total_texts.txt', 'w'))
        print 'generating'
        return labeled, unlabeled
    
    def split_labeled_unlabeld_and_test(self):
        self.get_texts(self.text_path)
        data = pd.read_csv(self.text_path)
        l = list(data['text'])
        k = list(data['knowledge'])
        lab = list(data['label'])
        '''
        res = []
        for i in range(len(l)):
            res.append((l[i], i))
        pickle.dump(res, open('total_texts.txt', 'w'))
        
        import ipdb;
        ipdb.set_trace()
        '''
        unique_knowledge = data['knowledge'].unique()
        self.labeled_indexes = []
        #data = data[data['label'] != '聊天']
        for i in range(len(unique_knowledge)):
            data_of_know = data[data['knowledge'] == unique_knowledge[i]]
            inds = data_of_know.index.tolist()
            random.shuffle(inds)
            if len(inds) < 10:
                self.labeled_indexes = self.labeled_indexes + inds[:int(0.5*len(inds)) + 1]
            else:
                self.labeled_indexes = self.labeled_indexes + inds[:10]
            
        self.indexes = data.index.tolist()
        left_indexes = list(set(self.indexes) - set(self.labeled_indexes))
        random.shuffle(left_indexes)
        self.unlabeled_indexes, self.test_indexes = left_indexes[:int(0.8 * len(left_indexes))], left_indexes[int(0.8 * len(left_indexes)) :]
        labeled, unlabeled, test = data.loc[self.labeled_indexes], data.loc[self.unlabeled_indexes], data.loc[self.test_indexes]
        print len(self.unlabeled_indexes),len(self.test_indexes),len(self.labeled_indexes),len(self.indexes)
        test.to_csv('../data/test_undefined.csv')
        return labeled, unlabeled, test
    
    def trans_i_to_str_dic(self, dic):
        i_to_str_map = pickle.load(open('total_texts.txt'))
        for i in range(len(i_to_str_map)):
            self.t_map[i_to_str_map[i][1]] = i_to_str_map[i][0]
        new_dic = {}
        for key in dic:
            new_dic[self.t_map[key]] = dic[key]
        return new_dic
    
    def get_dict_of_questions(self):
        self.dic = pickle.load(open('../data/total_dic_results_xiaolai.txt', 'r'))#pickle.load(open('../data/total_dic_results.txt', 'r'))
        '''
        for key in self.dic:
            sim_result = self.dic[key]
            scores = [sim_result[k][2] for k in range(len(sim_result))]
            for m in range(len(scores)):
                for j in range(len(self.range) - 1):
                    if self.range[j] < float(scores[m]) <= self.range[j + 1]:
                        self.range_result[self.range[j + 1]] += 1
        xl = [0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95,1.0]
        col_value = []
        for i in range(len(xl)):
            col_value.append(self.range_result[xl[i]])
        plt.bar(range(5,105,5), col_value)
        plt.show()
        '''

        
        def update_unlabeled_data(self, new_undefined_path):
            origin_texts = [key for key in self.dic]
            cur_undefined = pd.read_csv(new_undefined_path)
            cur_texts = list(new_undefined['text'])
            new_texts = list(set(cur_texts) - set(origin_texts))
            return new_texts
        
        return self.dic

# %%
class active_learning():
    
    def __init__(self, labeled, unlabeled, test, dic,  k, word_util, map_):
        self.labeled = labeled
        self.unlabeled = unlabeled
        self.test = test
        self.labeled_texts = list(labeled['text'])
        self.unlabeled_texts = list(unlabeled['rq_question'])
        #self.test_texts = list(test['text'])
        self.dic = dic
        #self.real = list(test['knowledge'])
        self.unlabeled_indexes = unlabeled.index.tolist()
        self.k = k
        self.sets = []
        self.map = map_
        self.word_util = word_util
        
    def predict(self):
        pred = []
        print 'now labeled sets size is : ' + str(len(self.labeled_texts))
        for i in self.test.index.tolist():
            results = self.dic[i]
            res_in = []
            for res in results:
                ques, title, score = res
                if ques.encode('utf-8') in self.labeled_texts:
                    knowledge = self.labeled[self.labeled['text'] == ques.encode('utf-8')]['knowledge']
                    knowledge = knowledge.loc[knowledge.index.tolist()[0]]
                    res_in.append(knowledge)
            if len(res_in) == 0:
                res_in.append('聊天')
            sort_dic = sorted(Counter(res_in).items(), key = lambda item:item[1], reverse = True)
            final_pred = sort_dic[0][0]
            pred.append(final_pred)
        real = [self.real[i].decode('utf-8') for i in range(len(self.real))]
        preds = [pred[i].decode('utf-8') for i in range(len(pred))]
        print('classification_report :\n%s' % metrics.classification_report(real, preds)) 
        
    def select_set(self):
        ent_dict = {}
        count_dict = []
        for i in self.unlabeled_indexes[:len(self.unlabeled)]:
            results = dic[self.unlabeled.loc[i,'rq_question'].decode('utf-8')]
            res_in = []
            if i % 100 == 0:
                print i
            if results != None:
                for res in results:
                    ques, title, score = res
                    if ques.encode('utf-8') in self.labeled_texts and 0.45 <= float(score):
                        knowledge = self.labeled[self.labeled['text'] == ques.encode('utf-8')]['knowledge']
                        knowledge = knowledge.loc[knowledge.index.tolist()[0]]
                        res_in.append((knowledge, float(score)))
                if len(res_in) == 0:
                    res_in.append(('聊天',0.0000001))
                counter = {}
                total_score = 0.0000001
                for k in range(len(res_in)):
                    if res_in[k][0] not in counter:
                        counter[res_in[k][0]] = 0.0000001
                    counter[res_in[k][0]] += res_in[k][1]
                    total_score += res_in[k][1]
                ent = 0.0000001
                scores,ents, ent_dic = [], [], {}
                for key in counter:
                    scores.append(counter[key] / total_score)
                    p = counter[key] / total_score
                    logp = np.log2(p)
                    ent -= p * logp
            ents.append(ent)     
            ent_dict[i] = ent
            count_dict.append(counter)
        '''
        pickle.dump(ent_dict, open('../util/ent_dict.txt', 'w'))
        pickle.dump(count_dict, open('../util/count_dict.txt', 'w'))
        ent_dict = pickle.load(open('../util/ent_dict.txt', 'r'))
        count_dict = pickle.load(open('../util/count_dict.txt', 'r'))
        '''
        del_ = []
        for k_i in ent_dict:
            if type(self.unlabeled.loc[k_i,'rq_question']) != str or '提醒' in self.unlabeled.loc[k_i,'rq_question'] or self.unlabeled.loc[k_i,'choose'] == 0:
                del_.append(k_i)
        for d_i in del_:
            del ent_dict[d_i]
        sort_dic = sorted(ent_dict.items(), key = lambda item:item[1], reverse = True)[:self.k]
        cur_set_index = [sort_dic[k][0] for k in range(len(sort_dic))]
        cur_set_entropy = [sort_dic[k][1] for k in range(len(sort_dic))]
        cur_count = []
        for i in range(len(count_dict)):
            if i in cur_set_index:
                cur_count.append(count_dict[i])
        
        return cur_set_index, cur_set_entropy, cur_count
            
    def merge(self, cur_set, cur_set_entropy, cur_count):
        self.sets = [] 
        new_labeled = pd.concat((self.labeled, self.unlabeled.loc[cur_set]), axis = 0)
        print 'merge into file : '+ '../data/total_results/new_labeled_sum.csv'
        self.unlabeled.loc[cur_set,'rq_question'].to_csv('../data/total_results/new_labeled_sum.csv')   
        new_unlabeled = self.unlabeled.drop(cur_set, axis = 0)
        self.labeled = new_labeled
        self.unlabeled = new_unlabeled
        self.labeled_texts = list(self.labeled['text'])
        self.unlabeled_texts = list(self.unlabeled['rq_question'])
        self.unlabeled_indexes = new_unlabeled.index.tolist()

# %%
#if __name__=="__main__":
data_util = data('../data/data.txt', '../data/text.csv', '../data/knowledge.txt', '../data/label.txt')
word_util = word()
word_util.get_word2vec()
#labeled, unlabeled, test = data_util.split_labeled_unlabeld_and_test()
labeled, unlabeled = data_util.split_real_labeled_unlabeld_and_test()
test = None
labeled_texts = labeled['text']
#test_texts = test['text']
#dic = data_util.get_dict_of_questions()
# Out:
# generating

# %%
#t_dic = data_util.get_dict_of_questions()
dic = data_util.get_dict_of_questions()
#dic = data_util.trans_i_to_str_dic(t_dic)

# %%
total_words = [key for key in dic]

# %%
'一键'.decode('utf-8') in total_words
# Out:
# True

# %%
labeled_indexes, unlabeled_indexes = data_util.labeled_indexes, data_util.unlabeled_indexes
al = active_learning(labeled, unlabeled, test, dic, 500, word_util, data_util.t_map)
while len(al.unlabeled_indexes) > 500:
    print 'length of cur unlabeled index is : ' + str(len(al.unlabeled_indexes))
    #al.predict()
    cur_set, cur_set_entropy, cur_count = al.select_set()
    al.merge(cur_set, cur_set_entropy, cur_count)
    break
# Out:
# length of cur unlabeled index is : 19921
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# merge into file : ../data/total_results/new_labeled_sum.csv
# /home/works/dl-tools/anaconda2/envs/tfenv.v1.2/lib/python2.7/site-packages/ipykernel/__main__.py:97: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
ddd = pd.read_csv('../data/ooooo.csv')

# %%
new_ddd = pd.read_csv('../data/new_ooo.csv')
new_ddd
# Out:
#         rq_id          rq_question  rq_answer  \
# 0     3204355            我打了几次都打不上        NaN
# 1     3204356                 打卡个鸡        NaN
# 2     3204357                打卡过了呀        NaN
# 3     3204358              系统是不是坏了        NaN
# 4     3204359           是你们系统好像有故障        NaN
# 5     3204360               老出现问题的        NaN
# 6     3204361             打了你们没有记录        NaN
# 7     3204362             没有记录怎么回事        NaN
# 8     3204363                  请看图        NaN
# 9     3204364                  我写了        NaN
# 10    3204365                我签过到的        NaN
# 11    3204366             这个是你们的问题        NaN
# 12    3204367                 绑定双鱼        NaN
# 13    3204368               09:34分        NaN
# 14    3204374           你为什么不给我打电话        NaN
# 15    3204340           19:10联系陆艺鑫        NaN
# 16    3204341            三年十万公里的质保        NaN
# 17    3204342                 任意时间        NaN
# 18    3204280                 豆豆处理        NaN
# 19    3204284              23号下午四点        NaN
# 20    3204285              22号送何燕玲        NaN
# 21    3204192     现在每天的订阅消息怎么没有推送了        NaN
# 22    3204195        十一点半打电话给我叫我吃饭        NaN
# 23    3204198        浦东金斜路这里有没有数码城        NaN
# 24    3204200          9/25 csdn课程        NaN
# 25    3204201             9.19来大姨妈        NaN
# 26    3204202              26日基金赎回        NaN
# 27    3204203          10月31日李卫东生日        NaN
# 28    3204204           11月24日陈磊生日        NaN
# 29    3204205            晚上六点半  快递        NaN
# ...       ...                  ...        ...
# 9526  3139140            周三下午三点半会议        NaN
# 9527  3139145              订阅全都打不开        NaN
# 9528  3139148                 打开没有        NaN
# 9529  3139072                 怎么领书        NaN
# 9530  3139077                23号取保        NaN
# 9531  3139036             什么叫着有点超钢        NaN
# 9532  3139037           嘉浚生日农历九月十一        NaN
# 9533  3139045         八点二十四分给丽华打电话        NaN
# 9534  3139049        请问8号忘打卡了不能补了吗        NaN
# 9535  3139050        我一定坚持坚持再坚持的打卡        NaN
# 9536  3139055        天平最大的缺点就是犹豫不定        NaN
# 9537  3139056            东京不都没有一红叉        NaN
# 9538  3139057               你不懂英文么        NaN
# 9539  3139058  可是这话对我而言..已经没用了[大哭]        NaN
# 9540  3139059          谢谢您朋友!/:sun        NaN
# 9541  3139063                感恩教师节        NaN
# 9542  3139064            小叶今天是什么日子        NaN
# 9543  3139065              爱你是我的功课        NaN
# 9544  3139066         怎么设置别人起床时的静音        NaN
# 9545  3139067                为什么不行        NaN
# 9546  3139068              晚上五点订蛋糕        NaN
# 9547  3139069             半小时体现我喝水        NaN
# 9548  3139070           周二晚上八点带身份证        NaN
# 9549  3139071           周二晚上八点装真份证        NaN
# 9550  3138934              你给我弄个图u        NaN
# 9551  3138935               那要怎么补签        NaN
# 9552  3138936                  也不能        NaN
# 9553  3138937                领月饼9点        NaN
# 9554  3138938          如何重新书写自己的星座        NaN
# 9555  3138942             晚上七点晚上九点        NaN
#
#                                      related_knowledges  is_deleted  \
# 0     114498:无法打卡/未收到打卡图:0.725|831:亲一口:0.609|1058:再叫...         1.0
# 1     114480:打卡操作:0.603|114494:打卡团打卡:0.578|961:重新生成打...         1.0
# 2     114480:打卡操作:0.644|114502:跨时区打卡:0.644|1128:联系了:...         1.0
# 3     114470:机器人确认:0.605|2821:系统出现问题或错误:0.598|1090:催...         1.0
# 4     2821:系统出现问题或错误:0.663|961:重新生成打卡图:0.606|968:怎么参...         1.0
# 5     2821:系统出现问题或错误:0.598|1260:失眠:0.580|961:重新生成打卡图...         1.0
# 6     2652:打卡变成第一天了:0.722|963:打卡记录:0.641|961:重新生成打卡图...         1.0
# 7      2652:打卡变成第一天了:0.667|963:打卡记录:0.631|1090:催促:0.617         1.0
# 8     2586:8月打卡图片:0.667|961:重新生成打卡图:0.667|114482:打卡图...         1.0
# 9      1908:发条短信给我妈:0.718|1264:好无聊:0.611|1308:干嘛呢:0.535         1.0
# 10    1317:哼:0.585|114498:无法打卡/未收到打卡图:0.571|961:重新生成...         1.0
# 11    1294:问你个问题:0.722|2821:系统出现问题或错误:0.690|1099:确认:...         1.0
# 12      941:星座运势:0.668|114475:修改手机号:0.576|1108:好了:0.572         1.0
# 13    922:怎么取消提醒:0.575|7824:如何找到自己想看的书?:0.474|2625:星...         1.0
# 14    917:为什么没有准时打电话给我:0.708|114514:共享提醒:0.668|11450...         1.0
# 15     1128:联系了:0.656|2829:有什么好的工作吗?:0.550|2843:好:0.532         1.0
# 16                                   1012:包月用车关键词:0.537         1.0
# 17    928:有没有倒计时功能:0.599|970:打卡改时间:0.576|1043:几点了:0.571         1.0
# 18    1117:怎么办:0.575|7827:怎样处理夫妻关系:0.555|114484:补签操作...         1.0
# 19    916:日程产品bug:0.548|2586:8月打卡图片:0.542|845:夸奖小来:0...         1.0
# 20    845:夸奖小来:0.570|916:日程产品bug:0.565|2586:8月打卡图片:0...         1.0
# 21    114521:无法收到订阅:0.688|2599:怎么修改订阅:0.669|947:星座运势...         1.0
# 22    114514:共享提醒:0.580|1041:不用打了:0.541|917:为什么没有准时打...         1.0
# 23                                   114504:晚打卡咨询:0.501         1.0
# 24                2586:8月打卡图片:0.483|114499:打卡时间过早:0.458         1.0
# 25    1906:女生来大姨妈饮食上应该注意什么:0.642|1259:好累啊:0.569|1291...         1.0
# 26          1336:傻逼:0.545|1337:我去:0.523|1312:生日快乐:0.522         1.0
# 27                                      1312:生日快乐:0.585         1.0
# 28    1312:生日快乐:0.650|916:日程产品bug:0.599|2811:7月8号是什么...         1.0
# 29       1168:你几点睡觉:0.537|1128:联系了:0.519|960:打卡时间:0.513         1.0
# ...                                                 ...         ...
# 9526    922:怎么取消提醒:0.613|1290:小来下午好:0.517|1090:催促:0.510         1.0
# 9527  916:日程产品bug:0.687|114521:无法收到订阅:0.673|2821:系统出...         1.0
# 9528  900:开启定位好处:0.659|2821:系统出现问题或错误:0.648|834:非常感谢...         1.0
# 9529  922:怎么取消提醒:0.573|968:怎么参加抽奖:0.550|11123:怎么穿衣服:...         1.0
# 9550    1.536539e+09    1.536539e+09         1.0         1.0     3.0       1
# 9551    1.536539e+09    1.536539e+09         1.0         1.0     3.0       1
# 9552    1.536539e+09    1.536539e+09         1.0         1.0     3.0       1
# 9553    1.536539e+09    1.536539e+09         1.0         1.0     3.0       0
# 9554    1.536539e+09    1.536539e+09         1.0         1.0     3.0       1
# 9555             NaN             NaN         NaN         NaN     NaN       0
#
# [9556 rows x 11 columns]

# %%
ind = new_ddd[new_ddd['choose'] == 0].index.tolist()

# %%
r
# Out:
#      14858          我们这里都有的贪官
# 0     3394            有事情需要帮忙
# 1    14637               他有多抠
# 2    18674             改了才有进步
# 3     9364               靖 小姐
# 4     4943      September 9th
# 5    18105             boh je
# 6    18886              向国 敬礼
# 7    10149              面膜 微购
# 8    11655          WeChat ID
# 9    11656          WeChat no
# 10   19585           tre   me
# 11    7632           Brush up
# 12    4197           Shut  up
# 13   11346     13870600709 刘峡
# 14   12038    李忠辉 13707916491
# 15    7412                ⊙ ⊙
# 16   15660                说的对
# 17    6968             有两位扫码了
# 18     593             就知道说这句
# 19   18149             嘻嘻 知道啦
# 20   11294            有钱啥都能解决
# 21    3805  还可以有这个功能呀/:strong
# 22    8365              没人 耐心
# 23    4655             太棒了 爱你
# 24    2163            在有一次不玩了
# 25   14045             我还说有月经
# 26   19844           5     没有
# 27    6581       噢!知道了!~太好了!~
# 28    2215          有什么想对我说的吗
# 29   17867              努力 幸运
# ..     ...                ...
# 469   6610              窒息的意思
# 470   4972            小来喜不喜欢我
# 471  14741         我还没准备好/::$
# 472   3021            我不需要睡觉吗
# 473  19767          我才知道什么叫女人
# 474  13453             是不是很想我
# 475  13904            那你干嘛不放弃
# 476  19326            这个世界找不到
# 477   7842               小来救我
# 478  12128           你们这个服务有点
# 479   3672              以前是女友
# 480  19190              别想不好的
# 481  11789            我抱着你就开心
# 482  18660            你老是那么早起
# 483   2396            聪明是一种天舞
# 484  14650              也不会化妆
# 485   8638               是有点色
# 486   7484           我的眼泪也还够了
# 487  19319               也就紧了
# 488  19320               /::$
# 489  10624            很舒服的感觉吗
# 490   4325             我不会将就的
# 491   2024              身高是多少
# 492  19395           亲爱哒还想插我吗
# 493   8630               都是酒味
# 494  11897               都是幻觉
# 495   4012           是经过自己的努力
# 496  16795             一切都会好的
# 497   3947        看看能不能创建一个快捷
# 498  12320              说的再好听
#
# [499 rows x 2 columns]

# %%
with open('../data/total_results/new_labeled_sum.csv','r') as f:
    dddd = f.read()
with open('../data/total_results/new_labeled_sum.csv','w') as f:
    f.write('index,text\n')
    f.write(dddd)

# %%
r = pd.read_csv('../data/total_results/new_labeled_sum.csv')
c = []
final_ind = []
final_results = []
r_ind = list(r['index'])
for i in range(len(r_ind)):
    if int(r_ind[i]) in ind:
        continue
    final_ind.append(r_ind[i])
    final_results.append(r.loc[i,'text'])
df = pd.DataFrame({'index':final_ind, 'text': final_results})
df.to_csv('final_al_results.csv',index = False)
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-56-2c3091cf7cdc> in <module>()
#       8         continue
#       9     final_ind.append(r_ind[i])
# ---> 10     final_results.append(r.loc[i,'text'])
#      11 df = pd.DataFrame({'index':final_ind, 'text': final_results})
#      12 df.to_csv('final_al_results.csv',index = False)
#
# /home/works/dl-tools/anaconda2/envs/tfenv.v1.2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /home/works/dl-tools/anaconda2/envs/tfenv.v1.2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# /home/works/dl-tools/anaconda2/envs/tfenv.v1.2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_lowerdim(self, tup)
#    1025                     return section
#    1026                 # This is an elided recursive call to iloc/loc/etc'
# -> 1027                 return getattr(section, self.name)[new_key]
#    1028
#    1029         raise IndexingError('not applicable')
#
# /home/works/dl-tools/anaconda2/envs/tfenv.v1.2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /home/works/dl-tools/anaconda2/envs/tfenv.v1.2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# /home/works/dl-tools/anaconda2/envs/tfenv.v1.2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# /home/works/dl-tools/anaconda2/envs/tfenv.v1.2/lib/python2.7/site-packages/pandas/core/indexing.pyc in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: u'the label [text] is not in the [index]'

# %%
df
# Out:
#      index              text
# 0    14858         我们这里都有的贪官
# 1     3394           有事情需要帮忙
# 2    14637              他有多抠
# 3    18674            改了才有进步
# 4    18105            boh je
# 5    18886             向国 敬礼
# 6    10149             面膜 微购
# 7    11655         WeChat ID
# 8    11656         WeChat no
# 9    19585          tre   me
# 10    4197          Shut  up
# 11   11346    13870600709 刘峡
# 12   12038   李忠辉 13707916491
# 13   15660               说的对
# 14   18149            嘻嘻 知道啦
# 15   11294           有钱啥都能解决
# 16    8365             没人 耐心
# 17    2163           在有一次不玩了
# 18   14045            我还说有月经
# 19   19844          5     没有
# 20   17867             努力 幸运
# 21     404           有补卡也没用吗
# 22    4193         你为什么要被我征服
# 23   19268        我就问你能不能发视频
# 24    7593             782 2
# 25   11641           你们建的有群吗
# 26    5968           要不你抱着我飞
# 27   19560         要不把我幻想你初恋
# 28    3464             162 3
# 29   13824             829 3
# ..     ...               ...
# 370  14701            定时是干啥啊
# 371   1261             我的良品呢
# 372   7326  哈哈哈 小来需要升级了  表情包
# 373   9793           可以教我英文吗
# 374   5272           不可以这么自私
# 375   5475               我想喝
# 376  19291       我刚才就是你刚才跟我说
# 377  15132         是不是有我你就开心
# 378  19180         你害怕有一天我消失
# 379  15061        不睡觉不就是为了做爱
# 380  14741        我还没准备好/::$
# 381   3021           我不需要睡觉吗
# 382  19767         我才知道什么叫女人
# 383  13453            是不是很想我
# 384  13904           那你干嘛不放弃
# 385  19326           这个世界找不到
# 386  12128          你们这个服务有点
# 387  19190             别想不好的
# 388  11789           我抱着你就开心
# 389  18660           你老是那么早起
# 390   2396           聪明是一种天舞
# 391  14650             也不会化妆
# 392  19319              也就紧了
# 393  19320              /::$
# 394  10624           很舒服的感觉吗
# 395   4325            我不会将就的
# 396  19395          亲爱哒还想插我吗
# 397  11897              都是幻觉
# 398  16795            一切都会好的
# 399  12320             说的再好听
#
# [400 rows x 2 columns]
